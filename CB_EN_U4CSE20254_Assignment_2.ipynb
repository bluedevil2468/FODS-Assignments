# %% [markdown]
# ASSIGNMENT-2

# %%
import pandas as pd

# %% [markdown]
# # MAIN **Q1**

# %% [markdown]
# *Q1*

# %%
data = pd.read_csv("https://raw.githubusercontent.com/flaviovdf/evcomp2018/master/data/nc-est2015-agesex-res.csv")
data
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0      0    0        3944153            3944160          3951330
# 1      0    1        3978070            3978090          3957888
# 2      0    2        4096929            4096939          4090862
# 3      0    3        4119040            4119051          4111920
# 4      0    4        4063170            4063186          4077551
# ..   ...  ...            ...                ...              ...
# 301    2   97          53582              53605            54118
# 302    2   98          36641              36675            37532
# 303    2   99          26193              26214            26074
# 304    2  100          44202              44246            45058
# 305    2  999      156964212          156969328        157258820
#
#      POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0            3963087          3926540          3931141          3949775
# ...

# %% [markdown]
# Q2

# %%
data.size
# Out:
# 3060

# %% [markdown]
# *Q3*

# %%
data.describe()
# Out:
#               SEX         AGE  CENSUS2010POP  ESTIMATESBASE2010  \
# count  306.000000  306.000000   3.060000e+02       3.060000e+02
# mean     1.000000   59.303922   4.035889e+06       4.036054e+06
# std      0.817834   98.060950   2.140881e+07       2.140968e+07
# min      0.000000    0.000000   6.073000e+03       6.075000e+03
# 25%      0.000000   25.000000   9.987065e+05       9.987415e+05
# 50%      1.000000   50.500000   2.045286e+06       2.045342e+06
# 75%      2.000000   76.000000   2.304370e+06       2.304525e+06
# max      2.000000  999.000000   3.087455e+08       3.087581e+08
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# count     3.060000e+02     3.060000e+02     3.060000e+02     3.060000e+02
# mean      4.043750e+06     4.074756e+06     4.105917e+06     4.136306e+06
# std       2.145038e+07     2.161430e+07     2.177900e+07     2.193965e+07
# min       6.104000e+03     6.606000e+03     7.459000e+03     8.159000e+03
# ...

# %% [markdown]
# *Q4*

# %%
data.rename(columns={'POPESTIMATE2010': '2010','POPESTIMATE2014': '2014'},inplace=True)
data
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
# ...

# %% [markdown]
# *Q5*

# %%
data.head(10)
# Out:
#    SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 0    0    0        3944153            3944160  3951330          3963087
# 1    0    1        3978070            3978090  3957888          3966551
# 2    0    2        4096929            4096939  4090862          3971565
# 3    0    3        4119040            4119051  4111920          4102470
# 4    0    4        4063170            4063186  4077551          4122294
# 5    0    5        4056858            4056872  4064653          4087709
# 6    0    6        4066381            4066412  4073013          4074993
# 7    0    7        4030579            4030594  4043046          4083225
# 8    0    8        4046486            4046497  4025604          4053203
# 9    0    9        4148353            4148369  4125415          4035710
#
#    POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 0          3926540          3931141  3949775          3978038
# ...

# %% [markdown]
# *Q6*

# %%
data.iloc[[14,21]]
# Out:
#     SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 14    0   14        4165982            4166059  4145614          4131501
# 21    0   21        4354294            4354603  4387956          4596166
#
#     POPESTIMATE2012  POPESTIMATE2013     2014  POPESTIMATE2015
# 14          4135460          4148966  4233839          4185386
# 21          4632892          4580130  4492373          4456790

# %% [markdown]
# *Q7*

# %%
data["change"] = 0
data["Percentage Change"] = 0
data
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010       2010  POPESTIMATE2011  \
# 0      0    0        3944153            3944160    3951330          3963087
# 1      0    1        3978070            3978090    3957888          3966551
# 2      0    2        4096929            4096939    4090862          3971565
# 3      0    3        4119040            4119051    4111920          4102470
# 4      0    4        4063170            4063186    4077551          4122294
# ..   ...  ...            ...                ...        ...              ...
# 301    2   97          53582              53605      54118            57159
# 302    2   98          36641              36675      37532            40116
# 303    2   99          26193              26214      26074            27030
# 304    2  100          44202              44246      45058            47556
# 305    2  999      156964212          156969328  157258820        158427085
#
# ...

# %% [markdown]
# *Q8*

# %%
graying=data.loc[(data['AGE']>=67) & (data['AGE']<=71)]
graying
# Out:
#      SEX  AGE  CENSUS2010POP  ESTIMATESBASE2010     2010  POPESTIMATE2011  \
# 67     0   67        2649365            2649426  2693707          2586302
# 68     0   68        2323672            2323736  2359816          2654106
# 69     0   69        2142324            2142381  2167830          2321925
# 70     0   70        2043121            2043178  2062577          2129707
# 71     0   71        1949323            1949391  1953607          2022972
# 169    1   67        1248906            1248938  1270145          1218999
# 170    1   68        1087296            1087339  1105699          1246765
# 171    1   69         994759             994797  1006782          1083646
# 172    1   70         945611             945642   954073           984933
# 173    1   71         900148             900187   903258           931570
# 271    2   67        1400459            1400488  1423562          1367303
# 272    2   68        1236376            1236397  1254117          1407341
# ...

# %% [markdown]
# *Q9*

# %%
girls=data.query("AGE==0 & SEX==0").shape[0]
boys=data.query("AGE==0 & SEX==1").shape[0]
print("Ration of Boys and Girls among Infants : ",boys/girls)
# Out:
# Ration of Boys and Girls among Infants :  1.0

# %% [markdown]
# *Q10*

# %%
res=(data.query("SEX==0").shape[0])/(data.query("SEX==1").shape[0])
res
# Out:
# 1.0

# %% [markdown]
# *Q11*

# %%
import matplotlib.pyplot as plt
data.plot(x='SEX',y='AGE')
plt.show()

# %% [markdown]
# #MAIN **Q2**

# %% [markdown]
# *Q1*

# %%
bask=pd.read_csv('https://github.com/flaviovdf/evcomp2018/raw/master/data/nba_salaries.csv')
bask
# Out:
#               PLAYER POSITION                TEAM     SALARY
# 0       Paul Millsap       PF       Atlanta Hawks  18.671659
# 1         Al Horford        C       Atlanta Hawks  12.000000
# 2     Tiago Splitter        C       Atlanta Hawks   9.756250
# 3        Jeff Teague       PG       Atlanta Hawks   8.000000
# 4        Kyle Korver       SG       Atlanta Hawks   5.746479
# ..               ...      ...                 ...        ...
# 412        Gary Neal       PG  Washington Wizards   2.139000
# 413     DeJuan Blair        C  Washington Wizards   2.000000
# 414  Kelly Oubre Jr.       SF  Washington Wizards   1.920240
# 415   Garrett Temple       SG  Washington Wizards   1.100602
# 416     Jarell Eddie       SG  Washington Wizards   0.561716
#
# [417 rows x 4 columns]

# %% [markdown]
# *Q2*

# %%
bask.size
# Out:
# 1668

# %% [markdown]
# *Q3*

# %%
bask.sort_values(by=['PLAYER'])
# Out:
#               PLAYER POSITION                    TEAM     SALARY
# 68      Aaron Brooks       PG           Chicago Bulls   2.250000
# 291     Aaron Gordon       PF           Orlando Magic   4.171680
# 59    Aaron Harrison       SG       Charlotte Hornets   0.525093
# 235    Adreian Payne       PF  Minnesota Timberwolves   1.938840
# 1         Al Horford        C           Atlanta Hawks  12.000000
# ..               ...      ...                     ...        ...
# 95   Wilson Chandler       SF          Denver Nuggets  10.449438
# 233      Zach LaVine       PG  Minnesota Timberwolves   2.148360
# 181    Zach Randolph       PF       Memphis Grizzlies   9.638555
# 86     Zaza Pachulia        C        Dallas Mavericks   5.200000
# 26      Zoran Dragic       SG          Boston Celtics   1.706225
#
# [417 rows x 4 columns]

# %% [markdown]
# *Q4*

# %%
bask.sort_values(by=['SALARY'],ascending=False)
# Out:
#                      PLAYER POSITION                 TEAM     SALARY
# 169             Kobe Bryant       SF   Los Angeles Lakers  25.000000
# 29              Joe Johnson       SF        Brooklyn Nets  24.894863
# 72             LeBron James       SF  Cleveland Cavaliers  22.970500
# 255         Carmelo Anthony       SF      New York Knicks  22.875000
# 131           Dwight Howard        C      Houston Rockets  22.359364
# ..                      ...      ...                  ...        ...
# 200         Elliot Williams       SG    Memphis Grizzlies   0.055722
# 324         Orlando Johnson       SG         Phoenix Suns   0.055722
# 327          Cory Jefferson       PF         Phoenix Suns   0.049709
# 326            Jordan McRae       SG         Phoenix Suns   0.049709
# 267  Thanasis Antetokounmpo       SF      New York Knicks   0.030888
#
# [417 rows x 4 columns]

# %%
bask.sort_values(by=['SALARY'])
# Out:
#                      PLAYER POSITION                 TEAM     SALARY
# 267  Thanasis Antetokounmpo       SF      New York Knicks   0.030888
# 327          Cory Jefferson       PF         Phoenix Suns   0.049709
# 326            Jordan McRae       SG         Phoenix Suns   0.049709
# 324         Orlando Johnson       SG         Phoenix Suns   0.055722
# 325            Phil Pressey       PG         Phoenix Suns   0.055722
# ..                      ...      ...                  ...        ...
# 131           Dwight Howard        C      Houston Rockets  22.359364
# 255         Carmelo Anthony       SF      New York Knicks  22.875000
# 72             LeBron James       SF  Cleveland Cavaliers  22.970500
# 29              Joe Johnson       SF        Brooklyn Nets  24.894863
# 169             Kobe Bryant       SF   Los Angeles Lakers  25.000000
#
# [417 rows x 4 columns]

# %% [markdown]
# *Q5*

# %%
bask.rename({'SALARY ($M)':'SALARY'},axis=1,inplace=True)
bask
# Out:
#               PLAYER POSITION                TEAM     SALARY
# 0       Paul Millsap       PF       Atlanta Hawks  18.671659
# 1         Al Horford        C       Atlanta Hawks  12.000000
# 2     Tiago Splitter        C       Atlanta Hawks   9.756250
# 3        Jeff Teague       PG       Atlanta Hawks   8.000000
# 4        Kyle Korver       SG       Atlanta Hawks   5.746479
# ..               ...      ...                 ...        ...
# 412        Gary Neal       PG  Washington Wizards   2.139000
# 413     DeJuan Blair        C  Washington Wizards   2.000000
# 414  Kelly Oubre Jr.       SF  Washington Wizards   1.920240
# 415   Garrett Temple       SG  Washington Wizards   1.100602
# 416     Jarell Eddie       SG  Washington Wizards   0.561716
#
# [417 rows x 4 columns]

# %% [markdown]
# *Q6*

# %%
bask.head()
# Out:
#            PLAYER POSITION           TEAM     SALARY
# 0    Paul Millsap       PF  Atlanta Hawks  18.671659
# 1      Al Horford        C  Atlanta Hawks  12.000000
# 2  Tiago Splitter        C  Atlanta Hawks   9.756250
# 3     Jeff Teague       PG  Atlanta Hawks   8.000000
# 4     Kyle Korver       SG  Atlanta Hawks   5.746479

# %% [markdown]
# *Q7*

# %%
bask.loc[2] #3rd Player
# Out:
# PLAYER      Tiago Splitter
# POSITION                 C
# TEAM         Atlanta Hawks
# SALARY             9.75625
# Name: 2, dtype: object

# %%
bask.loc[9] #10th Player
# Out:
# PLAYER      Tim Hardaway Jr.
# POSITION                  SG
# TEAM           Atlanta Hawks
# SALARY               1.30452
# Name: 9, dtype: object

# %%
bask.loc[21] #22nd Player
# Out:
# PLAYER      Jared Sullinger
# POSITION                  C
# TEAM         Boston Celtics
# SALARY              2.56926
# Name: 21, dtype: object

# %% [markdown]
# *Q8*

# %%
bask.sort_values(by='SALARY',ascending=False).head(5)
# Out:
#               PLAYER POSITION                 TEAM     SALARY
# 169      Kobe Bryant       SF   Los Angeles Lakers  25.000000
# 29       Joe Johnson       SF        Brooklyn Nets  24.894863
# 72      LeBron James       SF  Cleveland Cavaliers  22.970500
# 255  Carmelo Anthony       SF      New York Knicks  22.875000
# 131    Dwight Howard        C      Houston Rockets  22.359364

# %% [markdown]
# *Q9*

# %%
bask.loc[(bask['SALARY']>10)]
# Out:
#              PLAYER POSITION                TEAM     SALARY
# 0      Paul Millsap       PF       Atlanta Hawks  18.671659
# 1        Al Horford        C       Atlanta Hawks  12.000000
# 29      Joe Johnson       SF       Brooklyn Nets  24.894863
# 30   Thaddeus Young       PF       Brooklyn Nets  11.235955
# 42     Al Jefferson        C   Charlotte Hornets  13.500000
# ..              ...      ...                 ...        ...
# 368   DeMar DeRozan       SG     Toronto Raptors  10.050000
# 383  Gordon Hayward       SF           Utah Jazz  15.409570
# 400       John Wall       PG  Washington Wizards  15.851950
# 401    Nene Hilario        C  Washington Wizards  13.000000
# 402   Marcin Gortat        C  Washington Wizards  11.217391
#
# [69 rows x 4 columns]

# %% [markdown]
# *Q10*

# %%
s=bask.loc[bask['PLAYER']=='Stephen Curry']
print(s[['PLAYER','SALARY']])
# Out:
#             PLAYER     SALARY
# 121  Stephen Curry  11.370786

# %% [markdown]
# *Q11*

# %%
pg=bask.loc[(bask['POSITION']=='PG')&(bask['SALARY']>15)]
pg
# Out:
#                 PLAYER POSITION                   TEAM     SALARY
# 60        Derrick Rose       PG          Chicago Bulls  20.093064
# 74        Kyrie Irving       PG    Cleveland Cavaliers  16.407501
# 156         Chris Paul       PG   Los Angeles Clippers  21.468695
# 269  Russell Westbrook       PG  Oklahoma City Thunder  16.744218
# 400          John Wall       PG     Washington Wizards  15.851950

# %% [markdown]
# *Q12*

# %%
gold=bask.loc[bask['TEAM']=="Golden State Warriors"]
gold
# Out:
#                 PLAYER POSITION                   TEAM     SALARY
# 117      Klay Thompson       SG  Golden State Warriors  15.501000
# 118     Draymond Green       PF  Golden State Warriors  14.260870
# 119       Andrew Bogut        C  Golden State Warriors  13.800000
# 120     Andre Iguodala       SF  Golden State Warriors  11.710456
# 121      Stephen Curry       PG  Golden State Warriors  11.370786
# 122     Jason Thompson       PF  Golden State Warriors   7.008475
# 123   Shaun Livingston       PG  Golden State Warriors   5.543725
# 124    Harrison Barnes       SF  Golden State Warriors   3.873398
# 125  Marreese Speights        C  Golden State Warriors   3.815000
# 126    Leandro Barbosa       SG  Golden State Warriors   2.500000
# 127       Festus Ezeli        C  Golden State Warriors   2.008748
# 128       Brandon Rush       SF  Golden State Warriors   1.270964
# 129       Kevon Looney       SF  Golden State Warriors   1.131960
# ...

# %% [markdown]
# *Q13*

# %%
bask.groupby(bask['TEAM']).sum('SALARY')
# Out:
#                             SALARY
# TEAM
# Atlanta Hawks            69.573103
# Boston Celtics           50.285499
# Brooklyn Nets            57.306976
# Charlotte Hornets        84.102397
# Chicago Bulls            78.820890
# Cleveland Cavaliers     102.312412
# Dallas Mavericks         65.762559
# Denver Nuggets           62.429404
# Detroit Pistons          42.211760
# Golden State Warriors    94.085137
# Houston Rockets          85.285837
# Indiana Pacers           62.695023
# Los Angeles Clippers     66.074113
# Los Angeles Lakers       68.607944
# Memphis Grizzlies        93.796439
# Miami Heat               81.528667
# Milwaukee Bucks          52.258355
# Minnesota Timberwolves   65.847421
# New Orleans Pelicans     80.514606
# New York Knicks          69.404994
# Oklahoma City Thunder    96.832165
# Orlando Magic            77.623940
# Philadelphia 76ers       42.481345
# Phoenix Suns             50.520815
# Portland Trail Blazers   45.446878
# ...

# %% [markdown]
# *Q14*

# %%
bask.groupby(bask['POSITION']).count()
# Out:
#           PLAYER  TEAM  SALARY
# POSITION
# C             69    69      69
# PF            85    85      85
# PG            85    85      85
# SF            82    82      82
# SG            96    96      96

# %% [markdown]
# *Q15*

# %%
bask.groupby(bask['POSITION']).mean('SALARY')
# Out:
#             SALARY
# POSITION
# C         6.082913
# PF        4.951344
# PG        5.165487
# SF        5.532675
# SG        3.988195

# %% [markdown]
# # MAIN **Q3**

# %%
inst=pd.read_csv('https://github.com/flaviovdf/evcomp2018/raw/master/data/educ_inc.csv')
inst
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 0     1/1/08 0:00   00 to 17    Male  College, less than 4-yr degree
# 1     1/1/08 0:00   00 to 17  Female  College, less than 4-yr degree
# 2     1/1/08 0:00  65 to 80+    Male  College, less than 4-yr degree
# 3     1/1/08 0:00  65 to 80+  Female          No high school diploma
# 4     1/1/08 0:00   00 to 17  Female          No high school diploma
# ...           ...        ...     ...                             ...
# 1021  1/1/14 0:00   18 to 64  Female       High school or equivalent
# 1022  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 1023  1/1/14 0:00   18 to 64  Female          No high school diploma
# 1024  1/1/14 0:00   18 to 64  Female     Bachelor's degree or higher
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
#
#           Personal Income  Population Count
# 0     C: 10,000 to 14,999              1304
# 1       B: 5,000 to 9,999              1565
# ...

# %%
edu.loc[edu['Age']!='00 to 17'].sort_values(by='Age')

# %%
y=inst.loc[inst['Year']=='01-01-2014 0:00']
y[['Year','Population Count']]
# Out:
# Empty DataFrame
# Columns: [Year, Population Count]
# Index: []

# %% [markdown]
# *Q1*

# %%
inst.groupby('Educational Attainment').sum('Population Count')
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher             54617676
# College, less than 4-yr degree          52137494
# High school or equivalent               42942926
# No high school diploma                  40668871

# %% [markdown]
# *Q2*

# %%
inst.loc[inst['Age']!='00 to 17'].sort_values(by='Age')
# Out:
#              Year        Age  Gender          Educational Attainment  \
# 1025  1/1/14 0:00   18 to 64    Male     Bachelor's degree or higher
# 414   1/1/10 0:00   18 to 64  Female       High school or equivalent
# 413   1/1/10 0:00   18 to 64    Male  College, less than 4-yr degree
# 412   1/1/10 0:00   18 to 64    Male       High school or equivalent
# 411   1/1/10 0:00   18 to 64    Male       High school or equivalent
# ...           ...        ...     ...                             ...
# 481   1/1/11 0:00  65 to 80+    Male          No high school diploma
# 482   1/1/11 0:00  65 to 80+    Male     Bachelor's degree or higher
# 483   1/1/11 0:00  65 to 80+  Female  College, less than 4-yr degree
# 474   1/1/11 0:00  65 to 80+    Male     Bachelor's degree or higher
# 523   1/1/11 0:00  65 to 80+  Female  College, less than 4-yr degree
#
#           Personal Income  Population Count
# 1025   H: 75,000 and over           1628605
# 414   E: 25,000 to 34,999            363540
# ...

# %% [markdown]
# REQUIREMENT

# %% [markdown]
# *Q3*

# %%
inst.groupby('Educational Attainment').sum('Population Count')
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher             54617676
# College, less than 4-yr degree          52137494
# High school or equivalent               42942926
# No high school diploma                  40668871

# %% [markdown]
# *Q4*

# %%
total=inst['Population Count'].sum()
inst.loc[inst['Age']!='00 to 17'].groupby('Educational Attainment').sum('Population Count')*100/total
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher            28.683024
# College, less than 4-yr degree         27.339802
# High school or equivalent              22.497624
# No high school diploma                 16.338101

# %%
import random as rd
import time as t
import matplotlib.pyplot as plt

def times(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,1000))
    ti = selectionsort(l)
    return (ti)

def timebs(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,1000))
    ti = bubblesort(l)
    return (ti)

def timeis(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,1000))
    ti = insertionsort(l)
    return (ti)

def timems(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,1000))
    ti = mergesort(l)
    return (ti)

def timeqs(n):
  l=[]
  for i in range(n):
        l.append(rd.randint(0,1000))
  start = t.time()
  ti = quick(l,0,len(l)-1)
  end = t.time()
  return (end-start)


def selectionsort(l):
    start = t.time()
    for i in range(len(l)):
        mini = i
        for j in range(i,len(l)):
            if (l[mini]>l[j]):
                mini = j
        l[i],l[mini] = l[mini],l[i]
    end = t.time()
    return (end-start)

def bubblesort(l):
  start = t.time()
  for i in range(len(l)):
      for j in range(len(l)-i-1):
          if (l[j]>l[j+1]):
              l[j],l[j+1] = l[j+1],l[j]
  end = t.time()
  return (end-start)

def insertionsort(l):
  start = t.time()
  for i in range(len(l)):
      el = l[i]
      j = i-1
      while j >= 0 and el < l[j] :
          l[j + 1] = l[j]
          j -= 1
          l[j + 1] = el
  end = t.time()
  return (end-start)

def mergesort(l):
  start = t.time()
  if(len(l)>1):
    mid=len(l)//2
    L=l[:mid]
    R=l[mid:]
    mergesort(L)
    mergesort(R)
    i=0
    j=0
    k=0
    while(i<len(L) and j<len(R)):
      if(L[i]<R[j]):
        l[k]=L[i]
        i+=1
      else:
        l[k]=R[j]
        j+=1
      k+=1
    while(i<len(L)):
      l[k]=L[i]
      i+=1
      k+=1
    while(j<len(R)):
      l[k]=R[j]
      j+=1
      k+=1
  end = t.time()
  return (end-start)

def partition(l,st,en):
    i=(st-1)
    pivot=l[en]
    for j in range(st,en):
        if(l[j]<=pivot):
            i+=1
            l[i],l[j]=l[j],l[i]
            
    l[i+1],l[en]=l[en],l[i+1]
    return i+1

def quick(l,st,en):
    if(st<en):
        p=partition(l,st,en)
        quick(l,st,p-1)
        quick(l,p+1,en)
  
x = []
y = []
a = []
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
q=10
while(q<=10000):
    x.append(q)
    z = times(q)
    y.append(z)
    q+=100
q = 10
while(q<=10000):
    a.append(q)
    z = timebs(q)
    b.append(z)
    q+=100
q = 10
while(q<=10000):
    c.append(q)
    z = timeis(q)
    d.append(z)
    q+=100
q = 10
while(q<=10000):
    e.append(q)
    z = timeqs(q)
    f.append(z)
    q+=100
q = 10
while(q<=10000):
    g.append(q)
    z = timems(q)
    h.append(z)
    q+=100

plt.ylabel("Time")
plt.xlabel("Input size")
plt.plot(x,y,color='k',label='Selection Sort') #selection
plt.plot(a,b,color='blue',label='Bubble Sort') #bubble
plt.plot(c,d,color='green',label='Insertion Sort') #insertion
plt.plot(e,f,color='orange',label='Quick Sort') #quick
plt.plot(g,h,color='red',label='Merge Sort', ls = '--') #merge
plt.legend()
plt.show()

# %%
import random as rd
import time as t
import matplotlib.pyplot as plt
import numpy as np

def times(n):
    l = np.arange(n)
    ti = selectionsort(l)
    return (ti)

def times2(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,n))
    ti = selectionsort(l)
    return (ti)
  
x = []
y = []
a = []
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
q=10
while(q<=10000):
    x.append(q)
    z = times(q)
    y.append(z)
    q+=100
q=10
while(q<=10000):
    a.append(q)
    z = times2(q)
    b.append(z)
    q+=100

plt.ylabel("Time")
plt.xlabel("Input size")
plt.plot(x,y,color='k') #selection
plt.plot(a,b,color='red') #selection
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import random as rd
import time as t
import matplotlib.pyplot as plt
import numpy as np

def times(n):
    l = np.arange(n)
    ti = bubblesort(l)
    return (ti)

def times2(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,n))
    ti = bubblesort(l)
    return (ti)
  
x = []
y = []
a = []
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
q=10
while(q<=10000):
    x.append(q)
    z = times(q)
    y.append(z)
    q+=100
q=10
while(q<=10000):
    a.append(q)
    z = times2(q)
    b.append(z)
    q+=100

plt.ylabel("Time")
plt.xlabel("Input size")
plt.plot(x,y,color='k') #bubble
plt.plot(a,b,color='red') #bubble
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import random as rd
import time as t
import matplotlib.pyplot as plt
import numpy as np

def times(n):
    l = np.arange(n)
    ti = insertionsort(l)
    return (ti)

def times2(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,n))
    ti = insertionsort(l)
    return (ti)
  
x = []
y = []
a = []
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
q=10
while(q<=10000):
    x.append(q)
    z = times(q)
    y.append(z)
    q+=100
q=10
while(q<=10000):
    a.append(q)
    z = times2(q)
    b.append(z)
    q+=100

plt.ylabel("Time")
plt.xlabel("Input size")
plt.plot(x,y,color='k') #insertion
plt.plot(a,b,color='red') #insertion
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import random as rd
import time as t
import matplotlib.pyplot as plt
import numpy as np

def times(n):
    l = np.arange(n)
    ti = mergesort(l)
    return (ti)

def times2(n):
    l=[]
    for i in range(n):
        l.append(rd.randint(0,n))
    ti = mergesort(l)
    return (ti)
  
x = []
y = []
a = []
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
q=10
while(q<=10000):
    x.append(q)
    z = times(q)
    y.append(z)
    q+=100
q=10
while(q<=10000):
    a.append(q)
    z = times2(q)
    b.append(z)
    q+=100

plt.ylabel("Time")
plt.xlabel("Input size")
plt.plot(x,y,color='k') #merge
plt.plot(a,b,color='red') #merge
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
